# %%
# pip install nbimporter

# %%
# pip install nbformat

# %%
# Cell 1: Import Jupyter Notebook Loader
import nbimporter

# %%
# Cell 2: Import Functions from cpt_code_extractor.ipynb
from cpt_code_extractor import create_faiss_index, get_result

# %%
# import nbimporter
import unittest
from unittest.mock import patch, MagicMock
import os
import openai
# Cell 2: Import Functions from cpt_code_extractor.ipynb
from cpt_code_extractor import create_faiss_index, get_result


from cpt_code_extractor import create_faiss_index, get_result, llm  # Make sure to import your functions

class TestPDFSystem(unittest.TestCase):
    def setUp(self):
        # Setup that runs before each test function
        self.pdf_dir = "test_pdf_dir"
        self.valid_pdf = os.path.join(self.pdf_dir, "document.pdf")
        os.makedirs(self.pdf_dir, exist_ok=True)
        with open(self.valid_pdf, 'w') as f:
            f.write("PDF Content")

    def tearDown(self):
        # Cleanup after each test function
        os.remove(self.valid_pdf)
        os.rmdir(self.pdf_dir)

    @patch('os.listdir')
    def test_accept_only_pdf_files(self, mock_listdir):
        mock_listdir.return_value = ['document.pdf', 'document.txt', 'image.png']
        response = create_faiss_index(self.pdf_dir)
        self.assertIn("FAISS index created", response)

    def test_empty_directory_error(self):
        with patch('os.listdir', return_value=[]):
            response = create_faiss_index(self.pdf_dir)
            self.assertIn("Error: The directory does not contain any PDF files", response)

    @patch('cpt_code_extractor.faiss_index_created', False)
    def test_faiss_index_not_created(self):
        response = get_result("What is the CPT code for an MRI?")
        self.assertIn("Error: FAISS index not created", response)

    @patch('cpt_code_extractor.llm.query', return_value="Irrelevant text found")
    def test_irrelevant_text_handling(self):
        response = get_result("Random irrelevant text")
        self.assertIn("Irrelevant text found", response)

    # @patch('openai.ChatCompletion.create', side_effect=openai.error.OpenAIError("API down"))
    # def test_openai_api_downtime_handling(self):
    #     response = get_result("What is the CPT code for a CT scan?")
    #     self.assertIn("Error: OpenAI API is currently unavailable", response)
    
    @patch('openai.ChatCompletion.create', side_effect=openai.error.OpenAIError("API down"))
    def test_openai_api_downtime_handling(self):
        response = get_result("What is the CPT code for a CT scan?")
        self.assertIn("Error: OpenAI API is currently unavailable", response)

    @patch('os.listdir')
    def test_successful_multi_page_pdf_handling(self, mock_listdir):
        mock_listdir.return_value = ['multi-page-document.pdf']
        response = create_faiss_index(self.pdf_dir)
        self.assertIn("FAISS index created", response)

    @patch('cpt_code_extractor.get_result', return_value="Correct CPT code found")
    def test_successful_complex_query_response(self, mock_get_result):
        result = mock_get_result("Detailed query involving multiple conditions")
        self.assertIn("Correct CPT code found", result)

    def test_get_result_without_query_provides_error(self):
        response = get_result("")
        self.assertIn("Error: Please provide a query", response)

if __name__ == '__main__':
    unittest.main()

# %%
import unittest
import openai
from unittest.mock import patch
import cpt_code_extractor

class TestOpenAIDowntimeHandling(unittest.TestCase):

    def test_openai_api_downtime_handling(self):
        try:
            # Simulate a call to OpenAI that would raise an exception
            raise openai.error.OpenAIError("API down")
        except openai.error.OpenAIError as e:
            # Directly handle the exception and check its message
            self.assertEqual(str(e), "API down")

if __name__ == '__main__':
    unittest.main()

# %%
# Cell 3: Define Tests
import unittest

class TestCPTCodeExtractor(unittest.TestCase):

    def test_create_faiss_index_no_path(self):
        result = create_faiss_index("")
        self.assertIn("Error", result)

    # def test_create_faiss_index_invalid_path(self):
    #     result = create_faiss_index("/invalid/path")
    #     self.assertIn("Error", result)

    # def test_create_faiss_index_no_pdfs(self):
    #     result = create_faiss_index("/path/with/no/pdfs")
    #     self.assertIn("Error", result)

    # def test_get_result_no_index(self):
    #     result = get_result("Test query")
    #     self.assertIn("Error", result)

    # def test_get_result_no_query(self):
    #     global faiss_index_created
    #     faiss_index_created = True  # Simulate index creation
    #     result = get_result("")
    #     self.assertIn("Error", result)

# %%
# Cell 4: Run Tests
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ERROR:root:Directory path is missing
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %%
# IMPORTANT: You are using gradio version 4.16.0, however version 4.29.0 is available, please upgrade.

# %%
pip install gradio==4.29.0
# Out:
# Collecting gradio==4.29.0
#   Downloading gradio-4.29.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (5.2.0)
# Requirement already satisfied: fastapi in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.109.0)
# Requirement already satisfied: ffmpy in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.3.1)
# Collecting gradio-client==0.16.1 (from gradio==4.29.0)
#   Downloading gradio_client-0.16.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.19.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (3.8.0)
# Requirement already satisfied: numpy~=1.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (3.10.6)
# Requirement already satisfied: packaging in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (10.1.0)
# Requirement already satisfied: pydantic>=2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (2.5.2)
# Requirement already satisfied: pydub in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio==4.29.0)
#   Using cached python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio==4.29.0)
#   Downloading ruff-0.5.7-py3-none-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: semantic-version~=2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.12.0)
# Collecting typer<1.0,>=0.12 (from gradio==4.29.0)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (4.9.0)
# Requirement already satisfied: urllib3~=2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (2.0.7)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio==4.29.0) (0.27.0.post1)
# Requirement already satisfied: fsspec in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio-client==0.16.1->gradio==4.29.0) (2023.12.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from gradio-client==0.16.1->gradio==4.29.0) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from altair<6.0,>=4.2.0->gradio==4.29.0) (4.20.0)
# Requirement already satisfied: toolz in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from altair<6.0,>=4.2.0->gradio==4.29.0) (0.12.0)
# Requirement already satisfied: anyio in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from httpx>=0.24.1->gradio==4.29.0) (3.7.1)
# Requirement already satisfied: certifi in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from httpx>=0.24.1->gradio==4.29.0) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from httpx>=0.24.1->gradio==4.29.0) (1.0.2)
# Requirement already satisfied: idna in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from httpx>=0.24.1->gradio==4.29.0) (3.6)
# Requirement already satisfied: sniffio in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from httpx>=0.24.1->gradio==4.29.0) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.29.0) (0.14.0)
# Requirement already satisfied: filelock in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio==4.29.0) (3.13.1)
# Requirement already satisfied: requests in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio==4.29.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio==4.29.0) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from matplotlib~=3.0->gradio==4.29.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from matplotlib~=3.0->gradio==4.29.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from matplotlib~=3.0->gradio==4.29.0) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from matplotlib~=3.0->gradio==4.29.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from matplotlib~=3.0->gradio==4.29.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from matplotlib~=3.0->gradio==4.29.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio==4.29.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio==4.29.0) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from pydantic>=2.0->gradio==4.29.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from pydantic>=2.0->gradio==4.29.0) (2.14.5)
# Requirement already satisfied: click>=8.0.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio==4.29.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio==4.29.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio==4.29.0) (13.7.0)
# Requirement already satisfied: starlette<0.36.0,>=0.35.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from fastapi->gradio==4.29.0) (0.35.1)
# Requirement already satisfied: colorama in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio==4.29.0) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.29.0) (0.13.2)
# Requirement already satisfied: six>=1.5 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.29.0) (1.12.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.29.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.29.0) (2.17.2)
# Requirement already satisfied: exceptiongroup in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from anyio->httpx>=0.24.1->gradio==4.29.0) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.29.0) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in c:\samuel-work\6. accelerators\1. extract only images\visual extract\re_ internship connect _ satya  (1) (1)\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.29.0) (0.1.2)
# Downloading gradio-4.29.0-py3-none-any.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.3 MB 3.3 MB/s eta 0:00:04
#     --------------------------------------- 0.2/12.3 MB 2.4 MB/s eta 0:00:06
#     --------------------------------------- 0.3/12.3 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/12.3 MB 2.0 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/12.3 MB 1.8 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/12.3 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/12.3 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/12.3 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/12.3 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.7/12.3 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/12.3 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/12.3 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.9/12.3 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.3 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.3 MB 1.4 MB/s eta 0:00:08
#    --- ------------------------------------ 1.1/12.3 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.2/12.3 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.2/12.3 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/12.3 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.4/12.3 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.5/12.3 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.5/12.3 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/12.3 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/12.3 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.7/12.3 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.3 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.3 MB 1.5 MB/s eta 0:00:08
#    ------ --------------------------------- 1.9/12.3 MB 1.5 MB/s eta 0:00:08
#    ------ --------------------------------- 2.0/12.3 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 2.0/12.3 MB 1.5 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.3 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/12.3 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.2/12.3 MB 1.4 MB/s eta 0:00:07
#    ------- -------------------------------- 2.2/12.3 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.3/12.3 MB 1.4 MB/s eta 0:00:07
#    ------- -------------------------------- 2.4/12.3 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.5/12.3 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.6/12.3 MB 1.5 MB/s eta 0:00:07
#    -------- ------------------------------- 2.6/12.3 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.7/12.3 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.8/12.3 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 2.8/12.3 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 2.9/12.3 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 2.9/12.3 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 3.0/12.3 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.1/12.3 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.1/12.3 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.2/12.3 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.3/12.3 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.3/12.3 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.4/12.3 MB 1.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.5/12.3 MB 1.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.6/12.3 MB 1.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.6/12.3 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.7/12.3 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.9/12.3 MB 1.5 MB/s eta 0:00:06
#    ------------- -------------------------- 4.0/12.3 MB 1.5 MB/s eta 0:00:06
#    ------------- -------------------------- 4.2/12.3 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 4.4/12.3 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 4.5/12.3 MB 1.6 MB/s eta 0:00:05
#    --------------- ------------------------ 4.6/12.3 MB 1.6 MB/s eta 0:00:05
#    --------------- ------------------------ 4.8/12.3 MB 1.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.9/12.3 MB 1.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.1/12.3 MB 1.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.2/12.3 MB 1.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.3/12.3 MB 1.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.4/12.3 MB 1.7 MB/s eta 0:00:04
#    ------------------ --------------------- 5.6/12.3 MB 1.8 MB/s eta 0:00:04
#    ------------------ --------------------- 5.7/12.3 MB 1.8 MB/s eta 0:00:04
#    ------------------- -------------------- 5.8/12.3 MB 1.8 MB/s eta 0:00:04
#    ------------------- -------------------- 6.0/12.3 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 6.1/12.3 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 6.2/12.3 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 6.3/12.3 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 6.5/12.3 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 6.6/12.3 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 6.7/12.3 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.3 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.9/12.3 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.1/12.3 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.2/12.3 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.3 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 7.5/12.3 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 7.6/12.3 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 7.7/12.3 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 7.8/12.3 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 7.9/12.3 MB 1.9 MB/s eta 0:00:03
#    -------------------------- ------------- 8.0/12.3 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 8.2/12.3 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 8.4/12.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.5/12.3 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.6/12.3 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.7/12.3 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.3 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.0/12.3 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.3/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 9.6/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.3 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 9.9/12.3 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.3 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.3/12.3 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.3/12.3 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.3/12.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.4/12.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.6/12.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.9/12.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 11.2/12.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.4/12.3 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.7/12.3 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  12.2/12.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 2.2 MB/s eta 0:00:00
# Downloading gradio_client-0.16.1-py3-none-any.whl (314 kB)
#    ---------------------------------------- 0.0/314.6 kB ? eta -:--:--
#    --------------- ------------------------ 122.9/314.6 kB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 286.7/314.6 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  307.2/314.6 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 314.6/314.6 kB 1.8 MB/s eta 0:00:00
# Using cached python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.5.7-py3-none-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.7 MB 3.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/8.7 MB 3.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/8.7 MB 3.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/8.7 MB 3.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.7 MB 3.3 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/8.7 MB 3.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/8.7 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.2/8.7 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.7 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/8.7 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.7 MB 3.4 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.7 MB 3.4 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.7 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.7 MB 3.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.3/8.7 MB 3.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.7 MB 3.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/8.7 MB 3.3 MB/s eta 0:00:02
#    ------------ --------------------------- 2.7/8.7 MB 3.3 MB/s eta 0:00:02
#    ------------ --------------------------- 2.8/8.7 MB 3.2 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.7 MB 3.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.0/8.7 MB 3.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.2/8.7 MB 3.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.3/8.7 MB 3.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.7 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.6/8.7 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.7/8.7 MB 3.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.7/8.7 MB 3.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.8/8.7 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.9/8.7 MB 2.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.9/8.7 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 4.0/8.7 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 4.1/8.7 MB 2.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 2.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 2.7 MB/s eta 0:00:02
#    ------------------- -------------------- 4.3/8.7 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 4.4/8.7 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.5/8.7 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.6/8.7 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.6/8.7 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.7/8.7 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.8/8.7 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.9/8.7 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.9/8.7 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.7 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.1/8.7 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.1/8.7 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.2/8.7 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 5.4/8.7 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.5/8.7 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.6/8.7 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 5.7/8.7 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.7 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 5.9/8.7 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 6.1/8.7 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.2/8.7 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.3/8.7 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.4/8.7 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.5/8.7 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.7/8.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 6.9/8.7 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 7.2/8.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.4/8.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.5/8.7 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.7/8.7 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.8/8.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.9/8.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 8.2/8.7 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.6/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 2.3 MB/s eta 0:00:00
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.2 kB ? eta -:--:--
#    ---------------------------------- ----- 41.0/47.2 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 47.2/47.2 kB 474.0 kB/s eta 0:00:00
# Installing collected packages: ruff, python-multipart, typer, gradio-client, gradio
#   Attempting uninstall: ruff
#     Found existing installation: ruff 0.1.15
#     Uninstalling ruff-0.1.15:
#       Successfully uninstalled ruff-0.1.15
#   Attempting uninstall: python-multipart
#     Found existing installation: python-multipart 0.0.6
#     Uninstalling python-multipart-0.0.6:
#       Successfully uninstalled python-multipart-0.0.6
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 0.8.1
#     Uninstalling gradio_client-0.8.1:
#       Successfully uninstalled gradio_client-0.8.1
#   Attempting uninstall: gradio
#     Found existing installation: gradio 4.16.0
#     Uninstalling gradio-4.16.0:
#       Successfully uninstalled gradio-4.16.0
# Successfully installed gradio-4.29.0 gradio-client-0.16.1 python-multipart-0.0.9 ruff-0.5.7 typer-0.12.3
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.2 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Samuel-Work\6. Accelerators\1. Extract only Images\Visual Extract\RE_ Internship Connect _ Satya  (1) (1)\.venv\Scripts\python.exe -m pip install --upgrade pip
